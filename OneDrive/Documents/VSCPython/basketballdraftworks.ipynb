# %%
#Import statements
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import pymongo 
from pymongo import MongoClient
from datetime import date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf 
from tensorflow_addons.metrics import RSquare

# %%
#Uncomment line to delete collection
cluster = MongoClient("mongodb+srv://astone25:Butcanyou@cluster0.pxpfh.mongodb.net/basketball_website?retryWrites=true&w=majority")
db = cluster["basketball_website"]
collection = db['incoming_draftclass']
#collection.delete_many({})



#mongodb+srv://username:password@mflix-m5hjq.mongodb.net/test?retryWrites=true
#This finds a specific plaer if you want to
#Lonnie would be in a different collection but whatever
#thing = collection.find({'player':'Lonnie Walker IV'})
#for things in thing:
 #   print(thing)

# %%
#I wanna remove success score and just do wsPer48

# %%
#Success_score formula. 
def test_formula():
    cluster = MongoClient("mongodb+srv://astone25:Butcanyou@cluster0.pxpfh.mongodb.net/basketball_website?retryWrites=true&w=majority")
    db = cluster["basketball_website"]
    collection = db['basketball_reference_info']
    other_collection = db['nbadraft.net_stats']
    player_list = collection.find()
    print(player_list)
    dic = {}
    for player in player_list:
            #print(player)
        try:
            #total = (float(player['ws_per_48'])*100) + ((float(player['pts_per_g']))*float(player['fg_pct'])*1.5) + (float(player['ast_per_g'])*1.3) + (float(player['trb_per_g'])/3) + float(player['g'])/float(player['seasons']) + float(player['vorp'])/float(player['seasons'])
            
            #This is the success formula
            if float(player['vorp']) >= 0:
                vorp = float(player['vorp'])
            else:
                vorp=0
            if float(player['ws_per_48']) >= 0:
                ws = float(player['ws_per_48'])
            else:
                ws = 0
            total = float(player['mp_per_g'])+float(player['seasons'])/2.5+ws*105 + ((float(player['pts_per_g'])/1.2)*float(player['fg_pct'])*1.8) + (float(player['ast_per_g'])*1.25) + (float(player['trb_per_g'])/5) + vorp/float(player['seasons'])
            
            player_name = player['player']
            dic[player_name] = total
            other_collection.update_one({'player':player_name},{"$set":{"Success_score":total}}
            )
        except:
            pass
        
    sorted_dict = sorted(dic.items(),key = lambda kv: kv[1])
    return sorted_dict
    #sorted_age = sorted(dictionary_of_names.items(), key = lambda kv: kv[1])

test_formula()
# Out:
# <pymongo.cursor.Cursor object at 0x00000215F88B1190>
# [('Arnoldas Kulboka', 2.9),
#  ('Erik Murphy', 3.2889500000000003),
#  ('Royce White', 3.4),
#  ('Walter Sharpe', 3.526),
#  ('Patrick Ewing', 3.535),
#  ('Keith Benson', 3.6),
#  ('Sun Yue', 3.6956999999999995),
#  ('Ben Bentil', 3.84),
#  ('Kevin Murphy', 4.0024999999999995),
#  ('Petr Cornelie', 4.31945),
#  ('Darius Johnson-Odom', 4.3549999999999995),
#  ('Michael Gbinije', 4.369999999999999),
#  ('Diamond Stone', 4.4651),
#  ('Demetris Nichols', 4.7108),
#  ('Marcus Williams', 4.7547),
#  ('Robert Woodard II', 5.2287),
#  ('Tyler Bey', 5.247),
#  ('Marko Simonovic', 5.28095),
#  ('Taylor Griffin', 5.365),
#  ('George King', 6.04),
#  ('Kostas Antetokounmpo', 6.0875),
#  ('Kris Joseph', 6.258050000000001),
#  ('Taurean Green', 6.342000000000001),
#  ('Cameron Bairstow', 6.3828),
#  ('Tyrell Terry', 6.554499999999999),
#  ('Andy Rautins', 7.0196000000000005),
#  ('Tyler Honeycutt', 7.0652),
#  ('Kevin Hervey', 7.125450000000001),
#  ('Stephen Zimmerman', 7.291400000000001),
#  ('Nemanja Nedović', 7.383250000000001),
#  ('Trey Thompkins', 7.5598),
#  ('Russ Smith', 7.652),
#  ('Tornike Shengelia', 7.85945),
#  ('Marcus Paige', 7.9396),
#  ("Hamady N'Diaye", 8.0703),
#  ('Zhou Qi', 8.1784),
#  ('Grant Jerrett', 8.327000000000002),
#  ('Nigel Williams-Goss', 8.7123),
#  ('Tibor Pleiß', 9.03),
#  ('Vince Edwards', 9.1625),
#  ('Marial Shayok', 9.185),
#  ('Deividas Sirvydis', 9.33),
#  ('Leandro Bolmaro', 9.371500000000001),
#  ('Justin Harper', 9.43),
#  ('Craig Brackins', 9.4605),
#  ('C.J. Wilcox', 9.47),
#  ('Fab Melo', 9.605),
#  ('Pape Sy', 9.62385),
#  ('A.J. Hammons', 9.706500000000002),
#  ('Jamaal Franklin', 9.920499999999999),
#  ('Devon Hall', 9.96),
#  ('Darington Hobson', 10.004799999999998),
#  ('Damien Inglis', 10.092699999999999),
#  ('Ike Anigbogu', 10.139550000000002),
#  ('Cassius Stanley', 10.248000000000001),
#  ('Solomon Alabi', 10.2665),
#  ("Jahmi'us Ramsey", 10.427900000000001),
#  ('Josh Selby', 10.914),
#  ('D.J. Strawberry', 10.9245),
#  ('Tyshawn Taylor', 11.5649),
#  ('Sean Singletary', 11.724),
#  ('Jermareo Davidson', 11.811250000000001),
#  ('Dewan Hernandez', 11.931650000000001),
#  ('Nick Johnson', 11.933300000000001),
#  ('Melvin Frazier', 12.107),
#  ('J.R. Giddens', 12.1466),
#  ('Malachi Richardson', 12.1786),
#  ('Elijah Hughes', 12.2918),
#  ('Glen Rice Jr.', 12.43945),
#  ('Jared Cunningham', 12.547150000000002),
#  ('Peyton Siva', 12.6602),
#  ('Travis Leslie', 12.7547),
#  ('Ognjen Kuzmić', 12.757),
#  ('Caleb Swanigan', 12.866099999999998),
#  ('Kyle Guy', 12.933649999999998),
#  ('Cassius Winston', 12.95565),
#  ('Branden Dawson', 13.065000000000001),
#  ('Jay Scrubb', 13.103),
#  ('Quinndary Weatherspoon', 13.1838),
#  ('Bol Bol', 13.205900000000002),
#  ('Armon Johnson', 13.2671),
#  ('Devyn Marble', 13.398200000000001),
#  ('Derrick Caracter', 13.49),
#  ('Erick Green', 13.54805),
#  ('Morris Almond', 13.61165),
#  ('Daniel Hamilton', 13.674800000000001),
#  ('Kay Felder', 13.7998),
#  ('Justin James', 13.8908),
#  ('Lazar Hayward', 13.894449999999997),
#  ('Ricky Ledo', 13.9456),
#  ('DaJuan Summers', 13.9758),
#  ('Jacob Evans', 14.060400000000001),
#  ('Nolan Smith', 14.23645),
#  ('Brice Johnson', 14.3367),
#  ('Andrew Goudelock', 14.338),
#  ('Tyler Lydon', 14.385000000000002),
#  ('Marquis Teague', 14.509799999999998),
#  ('Joe Young', 14.709299999999999),
#  ('Carrick Felix', 14.74),
#  ('JaJuan Johnson', 14.770800000000001),
#  ('Gabe Pruitt', 14.838000000000001),
#  ('Kim English', 15.06625),
#  ('Lamar Patterson', 15.109700000000002),
#  ('Wade Baldwin', 15.14075),
#  ('Darrun Hilliard', 15.269599999999999),
#  ('Sasha Kaun', 15.31915),
#  ('Nathan Jawai', 15.432),
#  ('Jordan Bone', 15.452600000000002),
#  ('Mfiondu Kabengele', 15.5214),
#  ('Rashad Vaughn', 15.5615),
#  ('Džanan Musa', 15.7452),
#  ('Jeremy Tyler', 15.77),
#  ('Luka Šamanić', 15.916),
#  ('Carsen Edwards', 16.1102),
#  ('Vernon Carey Jr.', 16.1675),
#  ('Jordan Mickey', 16.3414),
#  ('Zhaire Smith', 16.4179),
#  ('Dominique Jones', 16.5169),
#  ('Darius Morris', 16.5508),
#  ('Kyrylo Fesenko', 16.676199999999998),
#  ('Justin Wright-Foreman', 16.73),
#  ('James Young', 16.77115),
#  ('Darnell Jackson', 16.9267),
#  ("Johnny O'Bryant", 16.9455),
#  ('Doron Lamb', 17.22525),
#  ('Willie Warren', 17.25235),
#  ('Tremont Waters', 17.429699999999997),
#  ('Henry Ellenson', 17.446649999999998),
#  ('Daniel Oturu', 17.45335),
#  ('Alando Tucker', 17.50145),
#  ('Alen Smailagić', 17.5135),
#  ('Lorenzo Brown', 17.5788),
#  ('Ray Spalding', 17.6116),
#  ('Dexter Pittman', 17.8025),
#  ('Demetrius Jackson', 17.895533333333336),
#  ('Quincy Miller', 18.0625),
#  ('Lester Hudson', 18.10375),
#  ('R.J. Hunter', 18.124499999999998),
#  ('Admiral Schofield', 18.260749999999998),
#  ('Sindarius Thornwell', 18.42125),
#  ('Adreian Payne', 18.465999999999998),
#  ('Pierre Jackson', 18.5228),
#  ('Chris McCullough', 18.7337),
#  ('Cleanthony Early', 18.771700000000003),
#  ('Miye Oni', 18.8),
#  ('Vlatko Čančar', 18.8298),
#  ('Joe Crawford', 18.834999999999997),
#  ('Joe Alexander', 18.868000000000002),
#  ('Victor Claver', 18.9804),
#  ('Chris Richard', 19.06155),
#  ('Devin Ebanks', 19.134),
#  ('Jermaine Taylor', 19.157100000000003),
#  ('Didi Louzada', 19.1754),
#  ('Jordan Adams', 19.309600000000003),
#  ('DeAndre Liggins', 19.361),
#  ('Anthony Bennett', 19.3972),
#  ('Isaiah Joe', 19.48025),
#  ('Charles Jenkins', 19.6487),
#  ('Bruno Fernando', 19.6996),
#  ('Jerome Robinson', 19.71025),
#  ('Sergey Karasev', 19.8825),
#  ('Malik Hairston', 20.138199999999998),
#  ('KZ Okpala', 20.2252),
#  ('Jarrell Brantley', 20.256800000000002),
#  ('Semaj Christon', 20.51075),
#  ('Josh Huestis', 20.6025),
#  ('Ryan Reid', 20.709999999999997),
#  ('Guerschon Yabusele', 20.7299),
#  ('Nico Mannion', 20.8233),
#  ('Jawun Evans', 20.9135),
#  ('Alec Peters', 20.9297),
#  ('Perry Jones', 20.941999999999997),
#  ('Tony Mitchell', 21.045499999999997),
#  ('Orlando Johnson', 21.1284),
#  ('Sam Merrill', 21.2166),
#  ('Rakeem Christmas', 21.301050000000004),
#  ('Ignas Brazdeikis', 21.445),
#  ('Luke Harangody', 21.4554),
#  ('Khyri Thomas', 21.501199999999997),
#  ('Damion James', 21.520500000000002),
#  ('Cory Jefferson', 21.520999999999997),
#  ('Chinanu Onuaku', 21.573500000000003),
#  ('Joel Bolomboy', 21.57475),
#  ('Nick Richards', 21.6106),
#  ('Reggie Perry', 21.71095),
#  ('Paul Zipser', 21.93555),
#  ('Mike Taylor', 21.9876),
#  ('Elliot Williams', 22.139350000000004),
#  ('Tyler Ennis', 22.204700000000003),
#  ('Tyrone Wallace', 22.238300000000006),
#  ('Thanasis Antetokounmpo', 22.25405),
#  ('Acie Law', 22.276049999999998),
#  ('Georgios Papagiannis', 22.296100000000003),
#  ('Kostas Papanikolaou', 22.4216),
#  ('Thomas Welsh', 22.7062),
#  ('Isaac Bonga', 22.768800000000002),
#  ('CJ Elleby', 22.836),
#  ('K.J. McDaniels', 22.9154),
#  ('Dylan Windler', 22.9844),
#  ('Sekou Doumbouya', 22.9942),
#  ('Anthony Brown', 23.0938),
#  ('Jabari Bird', 23.1365),
#  ('Aaron Nesmith', 23.2821),
#  ('Skylar Mays', 23.391549999999995),
#  ('Javaris Crittenton', 23.6539),
#  ('Xavier Henry', 23.666299999999996),
#  ('Elie Okobo', 23.704),
#  ('Jaron Blossomgame', 23.985899999999997),
#  ('Bernard James', 24.0101),
#  ('Earl Clark', 24.1748),
#  ('Edy Tavares', 24.20875),
#  ('Abdel Nader', 24.2182),
#  ('T.J. Leaf', 24.2354),
#  ('Jarvis Varnado', 24.2567),
#  ('Romeo Langford', 24.325),
#  ('Archie Goodwin', 24.36405),
#  ('Davon Reed', 24.4986),
#  ('Malcolm Lee', 24.5447),
#  ('Alize Johnson', 24.6),
#  ('Bruno Caboclo', 24.703900000000004),
#  ('Jarrett Culver', 24.709899999999998),
#  ('Daniel Orton', 24.726999999999997),
#  ('Robert Sacre', 24.751800000000003),
#  ('Jimmer Fredette', 24.796000000000003),
#  ('Markel Brown', 25.029000000000003),
#  ('P.J. Hairston', 25.197000000000003),
#  ('Donté Greene', 25.254900000000003),
#  ('Hasheem Thabeet', 25.4311),
#  ('Vernon Macklin', 25.484000000000005),
#  ('Robbie Hummel', 25.6403),
#  ('Jake Layman', 25.672),
#  ('Dominic McGuire', 25.76195),
#  ('Semi Ojeleye', 25.803400000000003),
#  ('Julian Wright', 25.88415),
#  ('Grant Riller', 26.0063),
#  ('Joey Dorsey', 26.0226),
#  ('Tyler Dorsey', 26.04445),
#  ('Justin Patton', 26.0584),
#  ('Jon Brockman', 26.097199999999997),
#  ('Thomas Robinson', 26.1295),
#  ('Jordan Nwora', 26.142),
#  ('Andrew Nicholson', 26.328),
#  ('Kevin Knox', 26.341949999999997),
#  ('Nando De Colo', 26.3853),
#  ('Kira Lewis Jr.', 26.4063),
#  ('D.J. Wilson', 26.4354),
#  ('Dakari Johnson', 26.5078),
#  ('Austin Daye', 26.595599999999997),
#  ('Anžejs Pasečņiks', 26.6214),
#  ('Sonny Weems', 26.628750000000004),
#  ('John Jenkins', 26.64916666666667),
#  ('Frank Ntilikina', 26.658799999999996),
#  ('Christian Eyenga', 26.82395),
#  ('Jordan McRae', 26.86595),
#  ('Chimezie Metu', 26.90645),
#  ('Chris Singleton', 26.9124),
#  ('Eric Maynor', 27.193400000000004),
#  ('Aaron Gray', 27.195899999999998),
#  ('Mitch McGary', 27.3932),
#  ('Byron Mullens', 27.4088),
#  ('Chandler Hutchison', 27.4702),
#  ('Jevon Carter', 27.7576),
#  ('Edmond Sumner', 27.832700000000003),
#  ('Timothé Luwawu-Cabarrot', 27.90035),
#  ('Sean Williams', 27.9393),
#  ('Udoka Azubuike', 27.9415),
#  ('Dragan Bender', 27.966900000000003),
#  ('Jarell Martin', 28.030399999999997),
#  ('Stéphane Lasme', 28.032799999999998),
#  ('Svi Mykhailiuk', 28.1152),
#  ('Luke Babbitt', 28.1526),
#  ('Semih Erden', 28.2422),
#  ('Jeff Taylor', 28.262349999999994),
#  ('Dwayne Bacon', 28.3469),
#  ('Kevin Séraphin', 28.397650000000002),
#  ('Justin Anderson', 28.406166666666664),
#  ('Rodions Kurucs', 28.501),
#  ('Jordan Hamilton', 28.515800000000002),
#  ('Josh Harrellson', 28.587833333333336),
#  ('Frank Mason III', 28.6048),
#  ('Keita Bates-Diop', 28.693600000000004),
#  ('Wes Iwundu', 28.782799999999995),
#  ('Terrence Williams', 28.8078),
#  ('Jan Veselý', 28.853399999999997),
#  ('Arnett Moultrie', 28.888800000000003),
#  ('R.J. Hampton', 28.9138),
#  ('James Anderson', 28.920699999999997),
#  ('Jerome Jordan', 29.0826),
#  ('Harry Giles', 29.17735),
#  ('Isaiah Whitehead', 29.2188),
#  ('Thon Maker', 29.2465),
#  ('Josh Green', 29.283000000000005),
#  ('Sam Young', 29.295400000000004),
#  ('Jeff Ayres', 29.400550000000003),
#  ('Jalen Harris', 29.450000000000003),
#  ('Jonah Bolden', 29.454700000000003),
#  ('Kadeem Allen', 29.472083333333334),
#  ('Daequan Cook', 29.6324),
#  ('Mario Hezonja', 29.685950000000002),
#  ('Goga Bitadze', 29.735833333333332),
#  ('Patrick McCaw', 29.873999999999995),
#  ('Malachi Flynn', 29.895000000000003),
#  ('Furkan Aldemir', 29.91485),
#  ('Nate Wolters', 29.994750000000003),
#  ('A.J. Price', 30.04266666666667),
#  ('Frank Jackson', 30.0455),
#  ('Ray McCallum', 30.147),
#  ('Nick Calathes', 30.212899999999998),
#  ('Nickeil Alexander-Walker', 30.213649999999998),
#  ('Álex Abrines', 30.244983333333334),
#  ('Jordan Williams', 30.3983),
#  ('Joffrey Lauvergne', 30.453599999999998),
#  ('Derrick Brown', 30.530333333333335),
#  ('Jarnell Stokes', 30.589933333333338),
#  ('Terrance Ferguson', 30.627000000000002),
#  ('Ty Jerome', 30.748700000000003),
#  ('Zeke Nnaji', 30.77205),
#  ('Ekpe Udoh', 30.787535714285717),
#  ('Dante Exum', 30.824849999999998),
#  ('Aleksej Pokusevski', 30.8492),
#  ('Nassir Little', 30.868499999999997),
#  ('Nik Stauskas', 31.024449999999998),
#  ('Nick Fazekas', 31.07015),
#  ('Alexis Ajinça', 31.268850000000004),
#  ('Ryan Kelly', 31.277000000000005),
#  ('Kyle Weaver', 31.302500000000002),
#  ('Cole Aldrich', 31.33555),
#  ('Quincy Pondexter', 31.35310714285714),
#  ('Sterling Brown', 31.567),
#  ('Sam Dekker', 31.6868),
#  ('Quincy Acy', 31.703400000000002),
#  ('MarShon Brooks', 31.744000000000003),
#  ('Juancho Hernangómez', 31.761799999999997),
#  ('Anthony Randolph', 31.78611666666666),
#  ('Georges Niang', 31.805216666666666),
#  ('Kendall Marshall', 31.9125),
#  ('Deyonta Davis', 31.968700000000002),
#  ('Jordan Bell', 32.1086),
#  ('Omari Spellman', 32.2034),
#  ('Jeff Withey', 32.24),
#  ('Justin Jackson', 32.2935),
#  ('Festus Ezeli', 32.3869),
#  ('Paul Reed', 32.394600000000004),
#  ('Henry Walker', 32.489),
#  ('Denzel Valentine', 32.507),
#  ('Damyean Dotson', 32.536249999999995),
#  ('Lonnie Walker IV', 32.627399999999994),
#  ("DeAndre' Bembry", 32.674899999999994),
#  ('Stanley Johnson', 32.6988),
#  ('D.J. White', 32.71195),
#  ('Shane Larkin', 32.80650000000001),
#  ('Tyler Ulis', 32.81375),
#  ('Ante Žižić', 32.909),
#  ('Tre Jones', 32.9964),
#  ('Aaron Holiday', 33.0264),
#  ('Troy Brown Jr.', 33.068400000000004),
#  ('Théo Maledon', 33.102199999999996),
#  ('Noah Vonleh', 33.18365000000001),
#  ('Glenn Robinson III', 33.27659285714286),
#  ('Jeremy Evans', 33.328678571428576),
#  ('Josh Okogie', 33.3788),
#  ('Yi Jianlian', 33.4674),
#  ('Zach Collins', 33.468),
#  ('Jason Smith', 33.5722),
#  ('Rodrigue Beaubois', 33.82535000000001),
#  ('Jalen McDaniels', 33.8475),
#  ('Tony Wroten', 33.92645),
#  ('Saben Lee', 34.1256),
#  ('Precious Achiuwa', 34.1494),
#  ('Darius Miller', 34.17315),
#  ('Marquese Chriss', 34.178399999999996),
#  ('Miles Plumlee', 34.18727142857143),
#  ('Justin Hamilton', 34.28726666666666),
#  ('Raul Neto', 34.33571428571429),
#  ('Darrell Arthur', 34.35900000000001),
#  ('Moritz Wagner', 34.43375),
#  ('Jalen Smith', 34.48975000000001),
#  ('Cheick Diallo', 34.5238),
#  ('Isaiah Canaan', 34.57765),
#  ('Norris Cole', 34.6385),
#  ('Vit Krejci', 34.6501),
#  ('Shabazz Napier', 34.691383333333334),
#  ('Chris Douglas-Roberts', 34.76535),
#  ('Jonny Flynn', 34.875),
#  ('Hamidou Diallo', 34.940000000000005),
#  ('Andrew Harrison', 34.9715),
#  ('Jaylen Nowell', 34.98056666666667),
#  ('Skal Labissière', 35.0686),
#  ('Furkan Korkmaz', 35.07925),
#  ('Josh Jackson', 35.2012),
#  ('Ivan Rabb', 35.430249999999994),
#  ('Grant Williams', 35.67523333333333),
#  ('Shabazz Muhammad', 35.6955),
#  ('Mike Scott', 35.70431666666667),
#  ('Donatas Motiejūnas', 35.745549999999994),
#  ('Lavoy Allen', 35.8812),
#  ('Lucas Nogueira', 36.018600000000006),
#  ('Cam Reddish', 36.03525),
#  ('Killian Hayes', 36.03980000000001),
#  ('Wesley Johnson', 36.080333333333336),
#  ('Jerian Grant', 36.16565),
#  ('Anfernee Simons', 36.2575),
#  ('Shelvin Mack', 36.270199999999996),
#  ('Malik Monk', 36.445800000000006),
#  ('Kyle Singler', 36.46549999999999),
#  ('Meyers Leonard', 36.596022222222224),
#  ('Jon Leuer', 36.8914),
#  ('Xavier Tillman Sr.', 36.968250000000005),
#  ('Solomon Hill', 36.991),
#  ('Obi Toppin', 37.07105000000001),
#  ('Ben McLemore', 37.074000000000005),
#  ('James Wiseman', 37.19775),
#  ('Brandon Rush', 37.30797777777778),
#  ('Trey Lyles', 37.70541428571428),
#  ('Darius Bazley', 37.765),
#  ('Payton Pritchard', 37.78725),
#  ('Mike Muscala', 38.04162222222222),
#  ('Emmanuel Mudiay', 38.086349999999996),
#  ('Derrick Byars', 38.107499999999995),
#  ('Dennis Smith Jr.', 38.1821),
#  ('Cody Martin', 38.25533333333334),
#  ('Deni Avdija', 38.27140000000001),
#  ('Tony Snell', 38.318650000000005),
#  ("Kyle O'Quinn", 38.3227),
#  ('Marreese Speights', 38.41415),
#  ('Cameron Payne', 38.52011428571428),
#  ('Eric Paschall', 38.5418),
#  ('Toney Douglas', 38.5806),
#  ('Tony Bradley', 38.7846),
#  ('Chase Budinger', 38.82478571428571),
#  ('Talen Horton-Tucker', 38.87615),
#  ('Dante Cunningham', 39.005300000000005),
#  ("E'Twaun Moore", 39.04675),
#  ('Derrick Williams', 39.06318571428571),
#  ('Jonas Jerebko', 39.21732222222222),
#  ('Jaden McDaniels', 39.26325),
#  ('Matisse Thybulle', 39.49000000000001),
#  ('Tyler Hansbrough', 39.52195),
#  ('Wayne Ellington', 39.59923076923077),
#  ('Pat Connaughton', 39.71539285714285),
#  ('Kosta Koufos', 39.77251818181818),
#  ('Andre Roberson', 39.79132142857142),
#  ('Malik Beasley', 39.79633333333333),
#  ('Tyler Zeller', 39.8278),
#  ('Jahlil Okafor', 39.8752),
#  ('Larry Sanders', 39.941333333333326),
#  ('Devin Vassell', 40.00164999999999),
#  ('James Ennis III', 40.175349999999995),
#  ('Glen Davis', 40.279),
#  ('Omri Casspi', 40.3949),
#  ("De'Anthony Melton", 40.428399999999996),
#  ('Damian Jones', 40.42933333333333),
#  ('Bismack Biyombo', 40.483999999999995),
#  ('DeJuan Blair', 40.509800000000006),
#  ('Ömer Aşık', 40.62510000000001),
#  ('Chuma Okeke', 40.6405),
#  ('Cedi Osman', 40.730000000000004),
#  ('Jordan Hill', 40.75945),
#  ('Alex Len', 40.76307222222223),
#  ('Kris Dunn', 40.767999999999994),
#  ('Dāvis Bertāns', 40.80519999999999),
#  ('Taurean Prince', 40.86533333333333),
#  ('Mo Bamba', 41.10125),
#  ('Doug McDermott', 41.123799999999996),
#  ('Trey Burke', 41.12788888888889),
#  ('Austin Rivers', 41.2976),
#  ('Landry Shamet', 41.585),
#  ('Isaiah Roby', 41.62508333333333),
#  ('Iman Shumpert', 41.7928),
#  ('Kenyon Martin Jr.', 41.884),
#  ('Grayson Allen', 42.0103),
#  ('Maurice Harkless', 42.035900000000005),
#  ('Nick Young', 42.0678),
#  ('Shake Milton', 42.21385),
#  ('Allen Crabbe', 42.224821428571424),
#  ('Josh McRoberts', 42.31757272727273),
#  ('Corey Brewer', 42.325096153846154),
#  ('Willy Hernangómez', 42.349066666666666),
#  ('Aaron Brooks', 42.41415000000001),
#  ('Jerryd Bayless', 42.58360000000001),
#  ('Tyus Jones', 42.61407142857142),
#  ('Landry Fields', 42.62460000000001),
#  ('Isaiah Hartenstein', 42.73),
#  ('Luc Mbah a Moute', 42.76006666666667),
#  ('Reggie Bullock', 42.774233333333335),
#  ('Justise Winslow', 42.778800000000004),
#  ('Frank Kaminsky', 42.81461428571429),
#  ('Jarred Vanderbilt', 42.97710000000001),
#  ('Patrick Patterson', 43.10507727272728),
#  ('Nemanja Bjelica', 43.373828571428575),
#  ('Kevon Looney', 43.40806428571428),
#  ('Jordan Crawford', 43.53296666666667),
#  ('Al Thornton', 43.6832),
#  ('John Henson', 43.781),
#  ('Spencer Hawes', 43.86885),
#  ('Rondae Hollis-Jefferson', 44.07483333333334),
#  ('Terance Mann', 44.10906666666666),
#  ('Trevor Booker', 44.11025),
#  ('Michael Beasley', 44.16581818181818),
#  ('Lance Stephenson', 44.24549999999999),
#  ('James Johnson', 44.28046923076923),
#  ('J.J. Hickson', 44.35875),
#  ('Patrick Williams', 44.422000000000004),
#  ('Bruce Brown', 44.5898),
#  ('Jodie Meeks', 44.654),
#  ('Michael Carter-Williams', 44.6884),
#  ('Marco Belinelli', 44.74304615384615),
#  ('Cory Joseph', 44.87814545454546),
#  ('Isaiah Stewart', 44.96235000000001),
#  ('Onyeka Okongwu', 44.9654),
#  ('Rodney Hood', 45.027),
#  ('Donte DiVincenzo', 45.1625),
#  ('Al-Farouq Aminu', 45.190909090909095),
#  ('Kelly Oubre Jr.', 45.34342857142857),
#  ('Terrence Ross', 45.580600000000004),
#  ('Greivis Vásquez', 45.62014285714286),
#  ('Jonathan Isaac', 45.74491666666666),
#  ('Jason Thompson', 45.8016),
#  ('Gorgui Dieng', 45.90111111111111),
#  ('Dillon Brooks', 45.92175),
#  ('Tomáš Satoranský', 46.04879999999999),
#  ('Michael Kidd-Gilchrist', 46.0874),
#  ('Nic Claxton', 46.12703333333334),
#  ('Patty Mills', 46.186107692307694),
#  ('Marcus Thornton', 46.19625),
#  ('Gerald Henderson', 46.197),
#  ('Luke Kennard', 46.205),
#  ('Jordan Poole', 46.2488),
#  ('Markelle Fultz', 46.2575),
#  ('Immanuel Quickley', 46.3003),
#  ('Jeremy Lamb', 46.30085),
#  ('Bobby Portis', 46.460499999999996),
#  ('Norman Powell', 46.46642142857143),
#  ('Kevin Porter Jr.', 46.5382),
#  ("De'Andre Hunter", 46.778200000000005),
#  ('Kyle Anderson', 46.7988),
#  ('Alec Burks', 46.863018181818184),
#  ('Avery Bradley', 46.871),
#  ('JaVale McGee', 46.93057142857143),
#  ('Jared Dudley', 47.085564285714284),
#  ('Isaac Okoro', 47.1248),
#  ('Jaxson Hayes', 47.24143333333333),
#  ('Dion Waiters', 47.29580000000001),
#  ('Ed Davis', 47.44461666666667),
#  ('Markieff Morris', 47.45164545454546),
#  ('Rudy Fernández', 47.64635),
#  ('Brandan Wright', 47.6735),
#  ('Delon Wright', 47.693828571428575),
#  ('Greg Oden', 47.78966666666666),
#  ('DeMarre Carroll', 47.83459090909092),
#  ('Evan Turner', 47.914699999999996),
#  ('Coby White', 48.12715),
#  ('Willie Cauley-Stein', 48.16277142857143),
#  ('Cameron Johnson', 48.29066666666666),
#  ('Rui Hachimura', 48.32149999999999),
#  ('Daniel Gafford', 48.360466666666674),
#  ('Dario Šarić', 48.37955),
#  ('Marvin Bagley III', 48.450399999999995),
#  ('Robin Lopez', 48.78051428571428),
#  ('Gary Trent Jr.', 49.019),
#  ('Cole Anthony', 49.06855000000001),
#  ('Nerlens Noel', 49.23405),
#  ('Kevin Huerter', 49.50010000000001),
#  ('Jared Sullinger', 49.5182),
#  ('Ramon Sessions', 49.57302727272728),
#  ('Roy Hibbert', 49.67388888888889),
#  ('Joe Harris', 49.734449999999995),
#  ('Jerami Grant', 49.8117),
#  ('Arron Afflalo', 50.12318181818182),
#  ('Jae Crowder', 50.174800000000005),
#  ('Josh Hart', 50.2975),
#  ('Terrence Jones', 50.3406),
#  ('P.J. Washington', 50.434133333333335),
#  ('Will Barton', 50.4642),
#  ('Cody Zeller', 50.52444444444445),
#  ('Tiago Splitter', 50.538178571428574),
#  ('OG Anunoby', 50.587),
#  ('Kelly Olynyk', 50.65028888888889),
#  ('Courtney Lee', 50.72773333333333),
#  ('Jakob Poeltl', 50.83826666666666),
#  ('Larry Nance Jr.', 50.96020714285714),
#  ('Tim Hardaway Jr.', 51.05703333333334),
#  ('Gary Harris', 51.0871),
#  ('Mario Chalmers', 51.09750555555556),
#  ('Elfrid Payton', 51.144549999999995),
#  ('D.J. Augustin', 51.148857142857146),
#  ('Ivica Zubac', 51.472649999999994),
#  ('Brandon Knight', 51.59155555555556),
#  ('Thomas Bryant', 51.607000000000006),
#  ('Jordan Clarkson', 51.6209),
#  ("Devonte' Graham", 51.7274),
#  ('Nikola Mirotić', 51.77435),
#  ('Dwight Powell', 51.866749999999996),
#  ('Danny Green', 52.19789615384615),
#  ('Saddiq Bey', 52.23355000000001),
#  ('Kentavious Caldwell-Pope', 52.252066666666664),
#  ('Marcus Morris', 52.481454545454554),
#  ('Terry Rozier', 52.560278571428576),
#  ('Caris LeVert', 52.7053),
#  ('Richaun Holmes', 52.73771428571429),
#  ('Carl Landry', 52.82255555555556),
#  ('Rodney Stuckey', 53.1497),
#  ('Jabari Parker', 53.2506),
#  ('Taj Gibson', 53.25415384615385),
#  ('Derrick White', 53.33449999999999),
#  ('Buddy Hield', 53.357166666666664),
#  ('Dennis Schröder', 53.35957777777778),
#  ('Jusuf Nurkić', 53.432500000000005),
#  ('Tristan Thompson', 53.54877272727273),
#  ('Nikola Peković', 53.74186666666667),
#  ('Monte Morris', 53.825750000000006),
#  ('Jalen Brunson', 53.922900000000006),
#  ('Wilson Chandler', 53.952916666666674),
#  ('Mason Plumlee', 53.96635555555556),
#  ('Josh Richardson', 54.28185714285714),
#  ('O.J. Mayo', 54.3228),
#  ('Kyle Kuzma', 54.3666),
#  ('Keldon Johnson', 54.37646666666666),
#  ('Jaren Jackson Jr.', 54.41610000000001),
#  ('Jeff Green', 54.44005714285714),
#  ('Reggie Jackson', 54.47887272727273),
#  ('Miles Bridges', 54.707300000000004),
#  ('Evan Fournier', 54.72025000000001),
#  ('Tyler Herro', 54.81533333333333),
#  ('RJ Barrett', 54.82749999999999),
#  ('Enes Freedom', 54.96730909090909),
#  ('Bogdan Bogdanović', 55.0107),
#  ('Tyrese Maxey', 55.029399999999995),
#  ('Dejounte Murray', 55.17125000000001),
#  ('Patrick Beverley', 55.314800000000005),
#  ('Otto Porter Jr.', 55.32818888888889),
#  ('Bojan Bogdanović', 55.3525),
#  ('Wendell Carter Jr.', 55.52290000000001),
#  ('Desmond Bane', 55.624),
#  ('Lauri Markkanen', 55.647099999999995),
#  ('Ryan Anderson', 55.70756666666667),
#  ('Aaron Gordon', 55.817499999999995),
#  ('Marcus Smart', 55.921499999999995),
#  ('Michael Porter Jr.', 56.13403333333333),
#  ('Spencer Dinwiddie', 56.3445),
#  ('T.J. Warren', 56.70275000000001),
#  ('Collin Sexton', 56.745000000000005),
#  ('Brandon Clarke', 56.90118333333333),
#  ('Derrick Favors', 57.30226666666667),
#  ('Kenneth Faried', 57.5391),
#  ("D'Angelo Russell", 57.96885714285714),
#  ('Jaylen Brown', 58.01341666666666),
#  ('Myles Turner', 58.16187857142857),
#  ('Anthony Edwards', 58.558049999999994),
#  ('Lonzo Ball', 58.824999999999996),
#  ('Harrison Barnes', 58.91595),
#  ('Chandler Parsons', 58.93443333333333),
#  ('Steven Adams', 59.17420555555556),
#  ('Mikal Bridges', 59.61755),
#  ('Jamal Murray', 59.7547),
#  ('Brandon Jennings', 60.04616111111112),
#  ('Darius Garland', 60.17396666666667),
#  ('Jeff Teague', 60.26186666666667),
#  ('Serge Ibaka', 60.46633461538462),
#  ('Thaddeus Young', 60.601733333333335),
#  ('George Hill', 60.672371428571424),
#  ('Eric Gordon', 60.69022857142858),
#  ('Robert Williams', 60.78240000000001),
#  ('Andrew Wiggins', 61.024600000000014),
#  ('Eric Bledsoe', 61.13526666666667),
#  ('Mitchell Robinson', 61.13720000000001),
#  ('Tyreke Evans', 61.16700000000001),
#  ('Greg Monroe', 61.602999999999994),
#  ('Montrezl Harrell', 61.62557142857143),
#  ('Nicolas Batum', 62.18033571428572),
#  ('Goran Dragić', 62.18228571428571),
#  ('Draymond Green', 62.34505),
#  ('Brandon Ingram', 62.41941666666666),
#  ('Darren Collison', 62.61443181818182),
#  ('Joakim Noah', 62.98389230769231),
#  ('Ricky Rubio', 63.13003181818183),
#  ('Victor Oladipo', 63.24902222222222),
#  ('Zach LaVine', 63.4092),
#  ('Malcolm Brogdon', 63.72466666666668),
#  ('Kristaps Porziņģis', 64.0924),
#  ('Jarrett Allen', 64.10740000000001),
#  ('Ty Lawson', 64.133),
#  ('Julius Randle', 64.2691),
#  ('DeAndre Jordan', 64.52573571428572),
#  ("De'Aaron Fox", 64.5313),
#  ('Pascal Siakam', 64.68095),
#  ('Hassan Whiteside', 64.8204),
#  ('Danilo Gallinari', 64.8552),
#  ('Jonas Valančiūnas', 64.9363),
#  ('Domantas Sabonis', 65.32939999999999),
#  ('Tobias Harris', 65.78323636363635),
#  ('Shai Gilgeous-Alexander', 65.9079),
#  ('CJ McCollum', 66.04344444444445),
#  ('Brook Lopez', 66.2474),
#  ('John Collins', 66.67025000000001),
#  ('Klay Thompson', 66.67705555555555),
#  ('Isaiah Thomas', 66.86633636363638),
#  ('Gordon Hayward', 66.90520000000001),
#  ('Khris Middleton', 66.9927),
#  ('Andre Drummond', 67.02300000000001),
#  ('LaMelo Ball', 67.14595),
#  ('Tyrese Haliburton', 67.46085),
#  ('DeMarcus Cousins', 67.55263636363638),
#  ('Clint Capela', 67.70139999999999),
#  ('Bam Adebayo', 68.4345),
#  ('Nikola Vučević', 68.50699090909089),
#  ('Derrick Rose', 68.70917692307692),
#  ('Deandre Ayton', 69.58555),
#  ('Devin Booker', 70.06639285714286),
#  ('Jrue Holiday', 70.4553076923077),
#  ('Marc Gasol', 71.05369230769232),
#  ('Ja Morant', 71.65986666666669),
#  ('Mike Conley', 71.94579999999999),
#  ('Kemba Walker', 72.2005909090909),
#  ('Jayson Tatum', 72.2156),
#  ('Bradley Beal', 73.00639999999999),
#  ('Donovan Mitchell', 73.19485000000002),
#  ('Al Horford', 73.55991666666668),
#  ('Kevin Love', 73.56097142857143),
#  ('DeMar DeRozan', 74.41646153846153),
#  ('Paul George', 76.30266666666667),
#  ('Rudy Gobert', 76.6346888888889),
#  ('John Wall', 76.76815),
#  ('Blake Griffin', 78.61543333333333),
#  ('Ben Simmons', 79.856),
#  ('Jimmy Butler', 79.95981818181819),
#  ('Trae Young', 81.098),
#  ('Kawhi Leonard', 81.75340000000001),
#  ('Kyrie Irving', 83.10959090909091),
#  ('Zion Williamson', 83.3792),
#  ('Joel Embiid', 84.04),
#  ('Karl-Anthony Towns', 85.78245714285715),
#  ('Russell Westbrook', 86.36531428571429),
#  ('Luka Dončić', 86.52720000000001),
#  ('Giannis Antetokounmpo', 86.82061111111112),
#  ('Anthony Davis', 88.06549999999999),
#  ('Damian Lillard', 88.2603),
#  ('Nikola Jokić', 90.42681428571429),
#  ('Stephen Curry', 91.78546538461538),
#  ('James Harden', 94.56716153846155),
#  ('Kevin Durant', 97.56894285714286)]

# %%
#Goes to mongodb folder of their basetkabll reference stuff, gets their name and finds their stuff on nbadraft.net
def get_all_their_draft_things():
    cluster = MongoClient("mongodb+srv://astone25:Butcanyou@cluster0.pxpfh.mongodb.net/basketball_website?retryWrites=true&w=majority")
    db = cluster["basketball_website"]
    collection = db['basketball_reference_info']
    for player in list:
        try:
            search_name = player['player'].replace(' ', '-')
            link = 'https://www.nbadraft.net/players/'+search_name+'/'
            year = player['Draft_Class']
            player_name = player['player']
            #adds to thing         finds the stuff 
            add_player_nbadraftnet(get_nbadraftnet_data(link,player_name,year))
        except:
            print(player)
#get_all_their_draft_things()

# %%
#scrapes basektball reference draft tables
def get_draft_class(site,year):
    print('1')
    all_teams = requests.get(site).text
    parser = bs(all_teams,"html.parser")
    body = parser.find_all('tbody')
    a = body[0].find_all('tr')
    for player in a:
        stats = player.findChildren()
        player_info = {'player': None,"g": None, "seasons": None, "college_name": None, "team_id": None, "pick_overall": None, "ranker": None, "Draft_Class": None,"mp": None, "pts": None, "trb": None, 'ast': None, "fg_pct": None, "fg3_pct": None, "ft_pct": None, "mp_per_g": None,"pts_per_g": None, "trb_per_g": None, 'ast_per_g': None, "ws": None, "ws_per_48": None, "bpm": None, "vorp": None}
        player_info['Draft_Class'] = year
        for stat in stats:          
            key = stat.get('data-stat')
            value = stat.text
            player_info[str(key)] = value
        add_player(player_info)
#twenty_one_class = get_draft_class('https://www.basketball-reference.com/draft/NBA_2021.html',2021)

# %%
#Got all the links for the incoming draft class on nbadraft.net
def get_incoming(site):
    all_teams = requests.get(site).text
    parser = bs(all_teams,"html.parser")
    #body = parser.find("table", class_="big-board-table sof-tablepress sticky-enabled dataTable no-footer")
    body = parser.find("table",{"class:big-board-table sof-tablepress sticky-enabled dataTable no-footer"})
    ##DataTables_Table_0
    soup = parser.find('table')
    thing = soup.find_all('a', href=True)
    link_list = []
    for a in thing:
        link_list.append(a['href'])
    return link_list
#twenty_two_class = get_incoming('https://www.nbadraft.net/ranking/bigboard/')
#twenty_two_class

# %%
#This'll get all the actual stuff, like the stats, for the incoming class and add it to the database
def add_incoming(link_list):
    
    for thing in link_list:
        name = thing[33:-1]
        add_player_incoming(get_nbadraftnet_data(thing,name,'2022'))
#add_incoming(get_incoming('https://www.nbadraft.net/ranking/bigboard/'))

# %%
#Scrapes nbadraft.net for all the stuff
#No lie, hella errors in this but i'm in a rush lmao, packs to move yknow
#If you wanna fix it later take out the try excepts, shitll take like twenty minutes tops
def get_nbadraftnet_data(link,player,year):
    player_info = {'player': None, 'international':None, "relative_age":None,"College":None, "Height":None, "Weight":None, "Position":None, "Number": None, "College_Year": None,  "Player_Comps": None, "MockPos": None, "BB_Pos":None,"Athleticism":None, "Size":None, "Defense":None, "Strength":None, "Quickness":None, "Leadership":None, "Jump Shot":None, "NBA Ready":None, "Ball Handling":None, "Potential":None, "Passing":None, "Passing":None, "Overall": None, "Success_score": None }
    all_teams = requests.get(link).text
    parser = bs(all_teams,"html.parser")
    try:
        number = (parser.find("span", class_="player-number").text).strip()
        player_info['Number'] = (number[:len(number)-1]).strip()
    except:
        pass

    
    player_info['player'] = player
    try:
        birthday = parser.find("span", class_="player-age").text
        birthday_num = birthday.index('y')
        birthday = float(birthday[1:birthday_num].strip())
        todays_year = date.today().year
        player_info["relative_age"] = abs((todays_year-int(year))-birthday)
    except:
        print('birthdate error')
        print(player)

    mock_pos = parser.find_all("span", class_="value")
    try:
        height = parser.find("span", class_="player-height").text
        index = height.index('-')
        player_info['Height'] = round(int(height[:index])+int(height[index+1:index+2])/12,2)
    except:
        print('height error')
        print(player)
    try:
        player_info['Weight'] = parser.find("span", class_="player-weight").text
    except:
        print('weight error')
        print(player)
    try:
        player_info['Position'] = parser.find("span", class_="player-position").text
    except:
        print('pos error')
        print(player)
    try:
        player_info['College'] = (parser.find("span", class_="team-title").text).strip()
    except:
        print('college error')
        print(player)
    try:
        player_info['College_Year'] = (parser.find("span", class_="team-class-of").text).strip()
    except:
        print('college year error')
        print(player)
    try:
        if (parser.find("span", class_="team-class-of").text).strip() == 'International':
            player_info['international'] == True
        else:
            player_info['international'] == False
    except:
        print(player)
        player_info['international'] == False
        print(player)
    
    atr_table = parser.find_all("div", class_="div-table-body")
    try:
        atr_table = atr_table[1]
    except:
        print(player)
        return player_info
    overall = 0
    counter = 0
    atr_table_list = atr_table.find_all('div', class_='div-table-row')
    for thing in atr_table_list:
        key = (thing.find("div", class_="div-table-cell attribute-name").text).strip()
        value = thing.find("div", class_="div-table-cell attribute-value").text
        player_info[key] = value
        try:
            overall+=int(value)
            counter+=1
        except:
            counter+=1
            overall+=(overall/counter)
            print(player)


    try:
        player_info['MockPos'] = mock_pos[0].text
        player_info['BB_Pos'] = mock_pos[1].text
        player_info['Overall'] = mock_pos[2].text
    except:
        player_info['Overall'] = overall
        
    return player_info
#get_nbadraftnet_data('https://www.nbadraft.net/players/jaden-ivey/','Jaden Ivey','2022')

# %%
#adds to the nbadraft.net mongo thing
def add_player_nbadraftnet(player_data):
    cluster = MongoClient("mongodb+srv://astone25:Butcanyou@cluster0.pxpfh.mongodb.net/basketball_website?retryWrites=true&w=majority")
    db = cluster["basketball_website"]
    collection = db["nbadraft.net_stats"]
    post = player_data
    collection.insert_one(post)

# %%
#adds to basektball reference mongo thing
def add_player(player_data):
    cluster = MongoClient("mongodb+srv://astone25:Butcanyou@cluster0.pxpfh.mongodb.net/basketball_website?retryWrites=true&w=majority")
    db = cluster["basketball_website"]
    collection = db['basketball_reference_info']
    post = player_data
    collection.insert_one(post)

# %%
def add_player_incoming(player_data):
    cluster = MongoClient("mongodb+srv://astone25:Butcanyou@cluster0.pxpfh.mongodb.net/basketball_website?retryWrites=true&w=majority")
    db = cluster["basketball_website"]
    collection = db['incoming_draftclass']
    post = player_data
    collection.insert_one(post)

# %%
#Goes iterates through the nba basketabll reference pages
def main_scraping_br():
    for i in range(2021-2007):
        year = str(i+2007)
        year_page = 'https://www.basketball-reference.com/draft/NBA_'+year+'.html'
        get_draft_class(year_page,year)
#main_scraping_br()

# %%
#gets dummy data 
def get_dummy_data(data,cols):
    for thing in cols:
        dummies =  pd.get_dummies(data[thing])
        data = pd.concat([data,dummies],axis = 1)
        data.drop(thing,axis=1,inplace=True)
    return data
#df2 = get_dummy_data(df2,['College','Position','Number','College_Year'])

# %%
counter = 0
#Fills in nones and na data with average values for height weight and the stats, then has mockpos and big board pos as just where they went in the draft
def conver(df,cols):
    counter = 0
    #df.at[row_label, column_label] = ‘Cell Value’
    for player in df.iloc():
        for index in df:
            if index == 'MockPos' or index == 'BB_Pos':
                if (pd.isnull(df[index][counter]) == True) or (df[index][counter] == None):
                 
                    df.at[counter, index] = ((counter+1)%60)+1
                else:
                    if int(df[index][counter]) > 70:
                        df.at[counter, index] = ((counter+1)%60)+1
                    else:
                        df[index][counter]
            elif index == 'Weight':
                if pd.isnull(df[index][counter]) == True | (df[index][counter] == None):
                    df.at[counter, index] = 219
                else:
                    df.at[counter, index] = int(df[index][counter])
            elif index == 'relative_age':
                try:
                    if (pd.isnull(df[index][counter]) == True) | (df[index][counter] == None):
                        df.at[counter, index] = 20
                    else:
                        df.at[counter, index] = int(df[index][counter])
                except:
                    print(player)
            elif index == 'Height':
                if pd.isnull(df[index][counter]) == True | (df[index][counter] == None):
                    df.at[counter, index] = 6.45
                else:
                    df.at[counter, index] = int(df[index][counter]) 
            elif index == 'Success_score':
                if pd.isna(df[index][counter]) == True:
                    df.at[counter, index] = 0
                else:
                    df.at[counter, index] = int(df[index][counter])          
            elif index in cols:
                if pd.isnull(df[index][counter]) == True or (df[index][counter] == None) or df[index][counter] == np.nan:
                    df.at[counter, index] = 7
                else:
            
                    try:
                        df.at[counter, index] = int(df[index][counter])
                    except ValueError:
                        df.at[counter,index] = 7
                    

        counter+=1
    return df

#df2=conver(df3,['Weight','MockPos','Athleticism','Size','Defense','Strength','Quickness','Leadership','Jump Shot','NBA Ready','Ball Handling','Potential','Passing','Overall','Intangibles','Rebounding','Post Skills'])

# %%
def add_player_fixed_database(player_data):
    cluster = MongoClient("mongodb+srv://astone25:Butcanyou@cluster0.pxpfh.mongodb.net/basketball_website?retryWrites=true&w=majority")
    db = cluster["basketball_website"]
    collection = db['nbadraftt_fixed']
    post = player_data
    collection.insert_one(post)

# %%
# just a box to convert the shit permently in a new mongothing, unrelateed
collection = db['nbadraft.net_stats']
df = pd.DataFrame(list(collection.find()))
df = conver(df,['Weight','MockPos','Athleticism','Size','Defense','Strength','Quickness','Leadership','Jump Shot','NBA Ready','Ball Handling','Potential','Passing','Overall','Intangibles','Rebounding','Post Skills'])

for thing in df.iloc():
    thing = dict(thing)
    add_player_fixed_database(thing)

# %%
#This splits the data into the ones with and without the the success_score and then formats it correctly

#Loads data and puts it in common document
#This is nesscary beause with dummy data it has to be all the same
cluster = MongoClient("mongodb+srv://astone25:Butcanyou@cluster0.pxpfh.mongodb.net/basketball_website?retryWrites=true&w=majority")
db = cluster["basketball_website"]
collection = db['incoming_draftclass']
df_new = pd.DataFrame(list(collection.find()))
collection = db['nbadraft.net_stats']
df = pd.DataFrame(list(collection.find()))
name = df['player']
new_names = df_new['player']
df_both = pd.concat([df,df_new])

#cols to drop
df_both = df_both.drop(columns=['international','_id','Player_Comps','Number','College','player'])

#Prepares data
df_both = df_both.reset_index()
df_both = get_dummy_data(conver(df_both,['MockPos','Weight','Overall','Size','Athleticism','Defense','Strength','Quickness','Leadership','Jump Shot','NBA Ready','Ball Handling','Potential','Passing','Intangibles','Rebounding','Post Skills']),['College_Year','Position'])
y= df_both['Success_score']

y = (df_both[0:820])['Success_score']
df_both = df_both.drop(columns=['Success_score'])
scaler = StandardScaler()

X = df_both[0:820]
X = np.asarray(X).astype(np.float32)
y = np.asarray(y).astype(np.float32)
X = scaler.fit_transform(X)

#Seperates data
df_test = df_both[820:]
test_X = scaler.fit_transform(df_test)

# %%
from tensorflow.keras.optimizers import RMSprop
#Main machine learning function, pretty self explanitory
#I put it as .999 for now cause i don't care about the testing, I just want it to be as accurate as possible for the final thing
#When it is set to .75 it typically has an error of 20, not bad 
#Wen I did it with .999 it had an error of like 7 which makes me feel good about myself lol, but expect an average error of like 15 probably
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=.8)
inputs = tf.keras.Input(shape=(X.shape[1],))
#inputs = tf.keras.Input(shape=(X.shape[1],))
layer1 = tf.keras.layers.Dense(16,activation='relu')(inputs)
layer2 = tf.keras.layers.Dense(16,activation='relu')(layer1)
layer3 = tf.keras.layers.Dense(16,activation='relu')(layer2)
layer4 = tf.keras.layers.Dense(16,activation='relu')(layer3)
layer5 = tf.keras.layers.Dense(16,activation='relu')(layer4)
layer6 = tf.keras.layers.Dense(16,activation='relu')(layer5)
layer7 = tf.keras.layers.Dense(16,activation='relu')(layer6)
layer8 = tf.keras.layers.Dense(16,activation='relu')(layer7)
layer9 = tf.keras.layers.Dense(16,activation='relu')(layer8)
layer10 = tf.keras.layers.Dense(16,activation='relu')(layer9)
layer11 = tf.keras.layers.Dense(16,activation='relu')(layer10)
layer12 = tf.keras.layers.Dense(16,activation='relu')(layer11)


output = tf.keras.layers.Dense(1)(layer12)
model = tf.keras.Model(inputs=inputs, outputs=output)
optimizer = RMSprop(0.0001)

model.compile(optimizer=optimizer,loss='mse',metrics='mse')

epoch_size = 100
history = model.fit(X_train,y_train,validation_split=.2,batch_size=32,epochs=epoch_size,verbose=0,validation_data=(X_test,y_test))
print(history)
# Out:
# <keras.callbacks.History object at 0x0000021582016370>

# %%
#loss and validation graphs
plt.figure(figsize=(14,10))
epoch_range = range(1,epoch_size+1)

train_loss = history.history['loss']
val_loss = history.history['val_loss']
plt.plot(epoch_range,train_loss,label="traning loss",color='red')
plt.plot(epoch_range,val_loss,label="validation loss",color = "blue")
plt.show()

# %%
#Checks mse ,take root for average error
y_pred = np.squeeze(model.predict(X_test))
result = RSquare()
result.update_state(y_test,y_pred)


print('R^2 score: ', result.result())
model.evaluate(X_test,y_test)
# Out:
# R^2 score:  tf.Tensor(0.3424365, shape=(), dtype=float32)
# 6/6 [==============================] - 0s 2ms/step - loss: 311.7186 - mse: 311.7186
# [311.71856689453125, 311.71856689453125]

# %%
# predict incoming data
model.save('basketball_predictor')
new_model = tf.keras.models.load_model('basketball_predictor')
new_stuff = new_model.predict([test_X])
# Out:
# INFO:tensorflow:Assets written to: basketball_predictor\assets

# %%
#Puts data into sorted dict
new_new_stuff = list(new_stuff)
new_new_names = list(new_names)
new_player_dict = {}
for i in range(len(new_new_stuff)):
    new_player_dict[new_new_names[i]] = new_new_stuff[i]
    #print(new_new_names[i],new_new_stuff[i])
    sorted_dict = sorted(new_player_dict.items(),key = lambda kv: kv[1],reverse=True)

# %%
sorted_dict
# Out:
# [('jaden-ivey', array([77.42013], dtype=float32)),
#  ('bennedict-mathurin', array([77.38989], dtype=float32)),
#  ('jabari-smith', array([74.87718], dtype=float32)),
#  ('paolo-banchero', array([70.0429], dtype=float32)),
#  ('keegan-murray', array([57.82653], dtype=float32)),
#  ('jalen-duren', array([57.51773], dtype=float32)),
#  ('kennedy-chandler', array([54.454338], dtype=float32)),
#  ('josh-minott', array([53.946686], dtype=float32)),
#  ('aj-griffin', array([53.748573], dtype=float32)),
#  ('chet-holmgren', array([52.276867], dtype=float32)),
#  ('johnny-davis', array([51.01615], dtype=float32)),
#  ('jeremy-sochan', array([49.736927], dtype=float32)),
#  ('shaedon-sharpe', array([48.634537], dtype=float32)),
#  ('tari-eason', array([48.147053], dtype=float32)),
#  ('tyty-washington', array([46.668365], dtype=float32)),
#  ('jaden-hardy', array([46.569912], dtype=float32)),
#  ('walker-kessler', array([45.068405], dtype=float32)),
#  ('michael-foster', array([44.598892], dtype=float32)),
#  ('kendall-brown', array([41.40005], dtype=float32)),
#  ('blake-wesley', array([41.25169], dtype=float32)),
#  ('max-christie', array([40.85891], dtype=float32)),
#  ('malaki-branham', array([40.65638], dtype=float32)),
#  ('mark-williams', array([39.568497], dtype=float32)),
#  ('bryce-mcgowens', array([37.739815], dtype=float32)),
#  ('marjon-beauchamp', array([37.563416], dtype=float32)),
#  ('ej-liddell', array([35.86319], dtype=float32)),
#  ('ochai-agbaji', array([35.7124], dtype=float32)),
#  ('christian-braun', array([34.72792], dtype=float32)),
#  ('leonard-miller', array([33.86641], dtype=float32)),
#  ('justyn-mutts', array([33.52913], dtype=float32)),
#  ('trevor-keels', array([33.186962], dtype=float32)),
#  ('wendell-moore', array([32.62291], dtype=float32)),
#  ('dereon-seabron', array([32.095512], dtype=float32)),
#  ('gabe-brown', array([31.524155], dtype=float32)),
#  ('michael-devoe', array([30.689175], dtype=float32)),
#  ('jordan-hall', array([30.682491], dtype=float32)),
#  ('jalen-wilson', array([29.465086], dtype=float32)),
#  ('jalen-williams', array([28.543158], dtype=float32)),
#  ('quenton-jackson', array([28.21096], dtype=float32)),
#  ('jake-laravia', array([28.0873], dtype=float32)),
#  ('jd-davison', array([27.715899], dtype=float32)),
#  ('emmanuel-akot', array([27.707481], dtype=float32)),
#  ('jamaree-bouyea', array([27.268272], dtype=float32)),
#  ('drew-timme', array([27.03555], dtype=float32)),
#  ('baylor-scheierman', array([27.002066], dtype=float32)),
#  ('taevion-kinsey', array([26.97709], dtype=float32)),
#  ('keve-aluma', array([26.875347], dtype=float32)),
#  ('tyrese-martin', array([26.575651], dtype=float32)),
#  ('jaylin-williams-auburn__trashed', array([25.58385], dtype=float32)),
#  ('matthew-mayer', array([25.576597], dtype=float32)),
#  ('scotty-pippen-jr', array([25.442762], dtype=float32)),
#  ('christian-koloko', array([24.973167], dtype=float32)),
#  ('justin-lewis', array([24.921032], dtype=float32)),
#  ('donovan-williams', array([24.729195], dtype=float32)),
#  ('iverson-molinar', array([24.562551], dtype=float32)),
#  ('tyler-burton', array([24.402115], dtype=float32)),
#  ('orlando-robinson', array([24.160305], dtype=float32)),
#  ('kris-murray', array([23.913803], dtype=float32)),
#  ('jean-montero', array([23.91109], dtype=float32)),
#  ('izaiah-brockington', array([23.886578], dtype=float32)),
#  ('jabari-walker', array([23.80057], dtype=float32)),
#  ('max-abmas', array([23.514572], dtype=float32)),
#  ('trayce-jackson-davis', array([23.17522], dtype=float32)),
#  ('bryson-williams', array([22.89973], dtype=float32)),
#  ('grant-sherfield', array([22.31033], dtype=float32)),
#  ('karlo-matkovic', array([22.2827], dtype=float32)),
#  ('ibou-dianko-badji', array([22.282192], dtype=float32)),
#  ('johnny-juzang', array([22.088558], dtype=float32)),
#  ('ron-harper-jr', array([21.519213], dtype=float32)),
#  ('keion-brooks', array([21.194307], dtype=float32)),
#  ('john-butler', array([21.167284], dtype=float32)),
#  ('caleb-houstan', array([21.056086], dtype=float32)),
#  ('peyton-watson', array([20.676266], dtype=float32)),
#  ('harrison-ingram', array([20.661676], dtype=float32)),
#  ('ismael-kamagate', array([19.232098], dtype=float32)),
#  ('julian-champagnie', array([19.132568], dtype=float32)),
#  ('julian-strawther', array([18.945372], dtype=float32)),
#  ('keon-ellis', array([18.80417], dtype=float32)),
#  ('jared-rhoden', array([18.541794], dtype=float32)),
#  ('alondes-williams', array([18.421495], dtype=float32)),
#  ('trevion-williams', array([18.388851], dtype=float32)),
#  ('kellan-grady', array([18.175835], dtype=float32)),
#  ('kameron-mcgusty', array([18.099365], dtype=float32)),
#  ('ryan-rollins', array([18.005463], dtype=float32)),
#  ('aminu-mohammed', array([17.01988], dtype=float32)),
#  ('ziga-samar', array([16.42109], dtype=float32)),
#  ('brady-manek', array([15.87973], dtype=float32)),
#  ('patrick-baldwin', array([15.877461], dtype=float32)),
#  ('gabriele-procida', array([15.281997], dtype=float32)),
#  ('luke-travers', array([14.503017], dtype=float32)),
#  ('ousmane-dieng', array([13.835716], dtype=float32)),
#  ('dyson-daniels', array([13.678091], dtype=float32)),
#  ('gui-santos', array([13.527246], dtype=float32)),
#  ('nikola-jovic', array([13.267075], dtype=float32)),
#  ('yannick-nzosa', array([13.2057], dtype=float32)),
#  ('matthew-strazel', array([13.127953], dtype=float32)),
#  ('matteo-spagnolo', array([12.789159], dtype=float32)),
#  ('malcolm-cazalon', array([12.498989], dtype=float32)),
#  ('jd-notae', array([11.609856], dtype=float32)),
#  ('hugo-besson', array([10.931131], dtype=float32))]
